# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.cbr.ru/scripts/XML_val.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><Valuta name="Foreign Currency Market Lib"><Item ID="R01010"><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><EngName>Australian Dollar</EngName><Nominal>1</Nominal><ParentCode>R01010    </ParentCode></Item><Item ID="R01015"><Name>\xc0\xe2\xf1\xf2\xf0\xe8\xe9\xf1\xea\xe8\xe9 \xf8\xe8\xeb\xeb\xe8\xed\xe3</Name><EngName>Austrian Shilling</EngName><Nominal>1000</Nominal><ParentCode>R01015    </ParentCode></Item><Item ID="R01020A"><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><EngName>Azerbaijan Manat</EngName><Nominal>1</Nominal><ParentCode>R01020    </ParentCode></Item><Item ID="R01035"><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><EngName>British Pound Sterling</EngName><Nominal>1</Nominal><ParentCode>R01035    </ParentCode></Item><Item ID="R01040F"><Name>\xc0\xed\xe3\xee\xeb\xfc\xf1\xea\xe0\xff \xed\xee\xe2\xe0\xff \xea\xe2\xe0\xed\xe7\xe0</Name><EngName>Angolan new Kwanza</EngName><Nominal>100000</Nominal><ParentCode>R01040    </ParentCode></Item><Item ID="R01060"><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xe9 \xe4\xf0\xe0\xec</Name><EngName>Armenia Dram</EngName><Nominal>1000</Nominal><ParentCode>R01060    </ParentCode></Item><Item ID="R01090B"><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><EngName>Belarussian Ruble</EngName><Nominal>1</Nominal><ParentCode>R01090    </ParentCode></Item><Item ID="R01095"><Name>\xc1\xe5\xeb\xfc\xe3\xe8\xe9\xf1\xea\xe8\xe9 \xf4\xf0\xe0\xed\xea</Name><EngName>Belgium Franc</EngName><Nominal>1000</Nominal><ParentCode>R01095    </ParentCode></Item><Item ID="R01100"><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><EngName>Bulgarian lev</EngName><Nominal>1</Nominal><ParentCode>R01100    </ParentCode></Item><Item ID="R01115"><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><EngName>Brazil Real</EngName><Nominal>1</Nominal><ParentCode>R01115    </ParentCode></Item><Item ID="R01135"><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xe9 \xf4\xee\xf0\xe8\xed\xf2</Name><EngName>Hungarian Forint</EngName><Nominal>100</Nominal><ParentCode>R01135    </ParentCode></Item><Item ID="R01200"><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><EngName>Hong Kong Dollar</EngName><Nominal>10</Nominal><ParentCode>R01200    </ParentCode></Item><Item ID="R01205"><Name>\xc3\xf0\xe5\xf7\xe5\xf1\xea\xe0\xff \xe4\xf0\xe0\xf5\xec\xe0</Name><EngName>Greek Drachma</EngName><Nominal>10000</Nominal><ParentCode>R01205    </ParentCode></Item><Item ID="R01215"><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><EngName>Danish Krone</EngName><Nominal>10</Nominal><ParentCode>R01215    </ParentCode></Item><Item ID="R01235"><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><EngName>US Dollar</EngName><Nominal>1</Nominal><ParentCode>R01235    </ParentCode></Item><Item ID="R01239"><Name>\xc5\xe2\xf0\xee</Name><EngName>Euro</EngName><Nominal>1</Nominal><ParentCode>R01239    </ParentCode></Item><Item ID="R01270"><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe0\xff \xf0\xf3\xef\xe8\xff</Name><EngName>Indian Rupee</EngName><Nominal>100</Nominal><ParentCode>R01270    </ParentCode></Item><Item ID="R01305"><Name>\xc8\xf0\xeb\xe0\xed\xe4\xf1\xea\xe8\xe9 \xf4\xf3\xed\xf2</Name><EngName>Irish Pound</EngName><Nominal>100</Nominal><ParentCode>R01305    </ParentCode></Item><Item ID="R01310"><Name>\xc8\xf1\xeb\xe0\xed\xe4\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><EngName>Iceland Krona</EngName><Nominal>10000</Nominal><ParentCode>R01310    </ParentCode></Item><Item ID="R01315"><Name>\xc8\xf1\xef\xe0\xed\xf1\xea\xe0\xff \xef\xe5\xf1\xe5\xf2\xe0</Name><EngName>Spanish Peseta</EngName><Nominal>10000</Nominal><ParentCode>R01315    </ParentCode></Item><Item ID="R01325"><Name>\xc8\xf2\xe0\xeb\xfc\xff\xed\xf1\xe ...

# %%
soup = BeautifulSoup(response.content, 'lxml')
soup
# Out:
# c:\program files\python39\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# <?xml version="1.0" encoding="windows-1251"?><html><body><valuta name="Foreign Currency Market Lib"><item id="R01010"><name>Австралийский доллар</name><engname>Australian Dollar</engname><nominal>1</nominal><parentcode>R01010    </parentcode></item><item id="R01015"><name>Австрийский шиллинг</name><engname>Austrian Shilling</engname><nominal>1000</nominal><parentcode>R01015    </parentcode></item><item id="R01020A"><name>Азербайджанский манат</name><engname>Azerbaijan Manat</engname><nominal>1</nominal><parentcode>R01020    </parentcode></item><item id="R01035"><name>Фунт стерлингов Соединенного королевства</name><engname>British Pound Sterling</engname><nominal>1</nominal><parentcode>R01035    </parentcode></item><item id="R01040F"><name>Ангольская новая кванза</name><engname>Angolan new Kwanza</engname><nominal>100000</nominal><parentcode>R01040    </parentcode></item><item id="R01060"><name>Армянский драм</name><engname>Armenia Dram</engname><nominal>1000</nominal><parentcode>R01060    </parentcode></item><item id="R01090B"><name>Белорусский рубль</name><engname>Belarussian Ruble</engname><nominal>1</nominal><parentcode>R01090    </parentcode></item><item id="R01095"><name>Бельгийский франк</name><engname>Belgium Franc</engname><nominal>1000</nominal><parentcode>R01095    </parentcode></item><item id="R01100"><name>Болгарский лев</name><engname>Bulgarian lev</engname><nominal>1</nominal><parentcode>R01100    </parentcode></item><item id="R01115"><name>Бразильский реал</name><engname>Brazil Real</engname><nominal>1</nominal><parentcode>R01115    </parentcode></item><item id="R01135"><name>Венгерский форинт</name><engname>Hungarian Forint</engname><nominal>100</nominal><parentcode>R01135    </parentcode></item><item id="R01200"><name>Гонконгский доллар</name><engname>Hong Kong Dollar</engname><nominal>10</nominal><parentcode>R01200    </parentcode></item><item id="R01205"><name>Греческая драхма</name><engname>Greek Drachma</engname><nominal>10000</nominal><parentcode>R01205    </parentcode></item><item id="R01215"><name>Датская крона</name><engname>Danish Krone</engname><nominal>10</nominal><parentcode>R01215    </parentcode></item><item id="R01235"><name>Доллар США</name><engname>US Dollar</engname><nominal>1</nominal><parentcode>R01235    </parentcode></item><item id="R01239"><name>Евро</name><engname>Euro</engname><nominal>1</nominal><parentcode>R01239    </parentcode></item><item id="R01270"><name>Индийская рупия</name><engname>Indian Rupee</engname><nominal>100</nominal><parentcode>R01270    </parentcode></item><item id="R01305"><name>Ирландский фунт</name><engname>Irish Pound</engname><nominal>100</nominal><parentcode>R01305    </parentcode></item><item id="R01310"><name>Исландская крона</name><engname>Iceland Krona</engname><nominal>10000</nominal><parentcode>R01310    </parentcode></item><item id="R01315"><name>Испанская песета</name><engname>Spanish Peseta</engname><nominal>10000</nominal><parentcode>R01315    </parentcode></item><item id="R01325"><name>Итальянская лира</name><engname>Italian Lira</engname><nominal>100000</nominal><parentcode>R01325    </parentcode></item><item id="R01335"><name>Казахстанский тенге</name><engname>Kazakhstan Tenge</engname><nominal>100</nominal><parentcode>R01335    </parentcode></item><item id="R01350"><name>Канадский доллар</name><engname>Canadian Dollar</engname><nominal>1</nominal><parentcode>R01350    </parentcode></item><item id="R01370"><name>Киргизский сом</name><engname>Kyrgyzstan Som</engname><nominal>100</nominal><parentcode>R01370    </parentcode></item><item id="R01375"><name>Китайский юань</name><engname>China Yuan</engname><nominal>10</nominal><parentcode>R01375    </parentcode></item><item id="R01390"><name>Кувейтский динар</name><engname>Kuwaiti Dinar</engname><nominal>10</nominal><parentcode>R01390    </parentcode></item><item id="R01405"><name>Латвийский лат</name><engname>Latvian Lat</engname><nominal>1</nominal><parentcode>R01405    </parentcode></item><item id="R ...

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="windows-1251"?>
# <html>
#  <body>
#   <valuta name="Foreign Currency Market Lib">
#    <item id="R01010">
#     <name>
#      Австралийский доллар
#     </name>
#     <engname>
#      Australian Dollar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01010
#     </parentcode>
#    </item>
#    <item id="R01015">
#     <name>
#      Австрийский шиллинг
#     </name>
#     <engname>
#      Austrian Shilling
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01015
#     </parentcode>
#    </item>
#    <item id="R01020A">
#     <name>
#      Азербайджанский манат
#     </name>
#     <engname>
#      Azerbaijan Manat
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01020
#     </parentcode>
#    </item>
#    <item id="R01035">
#     <name>
#      Фунт стерлингов Соединенного королевства
#     </name>
#     <engname>
#      British Pound Sterling
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01035
#     </parentcode>
#    </item>
#    <item id="R01040F">
#     <name>
#      Ангольская новая кванза
#     </name>
#     <engname>
#      Angolan new Kwanza
#     </engname>
#     <nominal>
#      100000
#     </nominal>
#     <parentcode>
#      R01040
#     </parentcode>
#    </item>
#    <item id="R01060">
#     <name>
#      Армянский драм
#     </name>
#     <engname>
#      Armenia Dram
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01060
#     </parentcode>
#    </item>
#    <item id="R01090B">
#     <name>
#      Белорусский рубль
#     </name>
#     <engname>
#      Belarussian Ruble
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01090
#     </parentcode>
#    </item>
#    <item id="R01095">
#     <name>
#      Бельгийский франк
#     </name>
#     <engname>
#      Belgium Franc
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01095
#     </parentcode>
#    </item>
#    <item id="R01100">
#     <name>
#      Болгарский лев
#     </name>
#     <engname>
#      Bulgarian lev
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01100
#     </parentcode>
#    </item>
#    <item id="R01115">
#     <name>
#      Бразильский реал
#     </name>
#     <engname>
#      Brazil Real
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01115
#     </parentcode>
#    </item>
#    <item id="R01135">
#     <name>
#      Венгерский форинт
#     </name>
#     <engname>
#      Hungarian Forint
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01135
#     </parentcode>
#    </item>
#    <item id="R01200">
#     <name>
#      Гонконгский доллар
#     </name>
#     <engname>
#      Hong Kong Dollar
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01200
#     </parentcode>
#    </item>
#    <item id="R01205">
#     <name>
#      Греческая драхма
#     </name>
#     <engname>
#      Greek Drachma
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01205
#     </parentcode>
#    </item>
#    <item id="R01215">
#     <name>
#      Датская крона
#     </name>
#     <engname>
#      Danish Krone
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01215
#     </parentcode>
#    </item>
#    <item id="R01235">
#     <name>
#      Доллар США
#     </name>
#     <engname>
#      US Dollar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01235
#     </parentcode>
#    </item>
#    <item id="R01239">
#     <name>
#      Евро
#     </name>
#     <engname>
#      Euro
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01239
#     </parentcode>
#    </item>
#    <item id="R01270">
#     <name>
#      Индийская рупия
#     </name>
#     <engname>
#      Indian Rupee
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01270
#     </parentcode>
#    </item>
#    <item id="R01305">
#     <name>
#      Ирландский фунт
#     </name>
#     <engname>
#      Irish Pound
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01305
#     </parentcode>
#    </item>
#    <item id="R01310">
#     <name>
#      Исландская крона
#     </name>
#     <engname>
#      Iceland Krona
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01310
#     </parentcode>
#    </item>
#    <item id="R01315">
#     <name>
#      Испанская песета
#     </name>
#     <engname>
#      Spanish Peseta
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01315
#     </parentcode>
#    </item>
#    <item id="R01325">
#     <name>
#      Итальянская лира
#     </name>
#     <engname>
#      Italian Lira
#     </engname>
#     <nominal>
#      100000
#     </nominal>
#     <parentcode>
#      R01325
#     </parentcode>
#    </item>
#    <item id="R01335">
#     <name>
#      Казахстанский тенге
#     </name>
#     <engname>
#      Kazakhstan Tenge
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01335
#     </parentcode>
#    </item>
#    <item id="R01350">
#     <name>
#      Канадский доллар
#     </name>
#     <engname>
#      Canadian Dollar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01350
#     </parentcode>
#    </item>
#    <item id="R01370">
#     <name>
#      Киргизский сом
#     </name>
#     <engname>
#      Kyrgyzstan Som
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01370
#     </parentcode>
#    </item>
#    <item id="R01375">
#     <name>
#      Китайский юань
#     </name>
#     <engname>
#      China Yuan
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01375
#     </parentcode>
#    </item>
#    <item id="R01390">
#     <name>
#      Кувейтский динар
#     </name>
#     <engname>
#      Kuwaiti Dinar
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01390
#     </parentcode>
#    </item>
#    <item id="R01405">
#     <name>
#      Латвийский лат
#     </name>
#     <engname>
#      Latvian Lat
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01405
#     </parentcode>
#    </item>
#    <item id="R01420">
#     <name>
#      Ливанский фунт
#     </name>
#     <engname>
#      Lebanese Pound
#     </engname>
#     <nominal>
#      100000
#     </nominal>
#     <parentcode>
#      R01420
#     </parentcode>
#    </item>
#    <item id="R01435">
#     <name>
#      Литовский лит
#     </name>
#     <engname>
#      Lithuanian Lita
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01435
#     </parentcode>
#    </item>
#    <item id="R01436">
#     <name>
#      Литовский талон
#     </name>
#     <engname>
#      Lithuanian talon
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01435
#     </parentcode>
#    </item>
#    <item id="R01500">
#     <name>
#      Молдавский лей
#     </name>
#     <engname>
#      Moldova Lei
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01500
#     </parentcode>
#    </item>
#    <item id="R01510">
#     <name>
#      Немецкая марка
#     </name>
#     <engname>
#      Deutsche Mark
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01510
#     </parentcode>
#    </item>
#    <item id="R01510A">
#     <name>
#      Немецкая марка
#     </name>
#     <engname>
#      Deutsche Mark
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01510
#     </parentcode>
#    </item>
#    <item id="R01523">
#     <name>
#      Нидерландский гульден
#     </name>
#     <engname>
#      Netherlands Gulden
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01523
#     </parentcode>
#    </item>
#    <item id="R01535">
#     <name>
#      Норвежская крона
#     </name>
#     <engname>
#      Norwegian Krone
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01535
#     </parentcode>
#    </item>
#    <item id="R01565">
#     <name>
#      Польский злотый
#     </name>
#     <engname>
#      Polish Zloty
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01565
#     </parentcode>
#    </item>
#    <item id="R01570">
#     <name>
#      Португальский эскудо
#     </name>
#     <engname>
#      Portuguese Escudo
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01570
#     </parentcode>
#    </item>
#    <item id="R01585">
#     <name>
#      Румынский лей
#     </name>
#     <engname>
#      Romanian Leu
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01585
#     </parentcode>
#    </item>
#    <item id="R01585F">
#     <name>
#      Румынский лей
#     </name>
#     <engname>
#      Romanian Leu
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01585
#     </parentcode>
#    </item>
#    <item id="R01589">
#     <name>
#      СДР (специальные права заимствования)
#     </name>
#     <engname>
#      SDR
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01589
#     </parentcode>
#    </item>
#    <item id="R01625">
#     <name>
#      Сингапурский доллар
#     </name>
#     <engname>
#      Singapore Dollar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01625
#     </parentcode>
#    </item>
#    <item id="R01665A">
#     <name>
#      Суринамский доллар
#     </name>
#     <engname>
#      Surinam Dollar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01665
#     </parentcode>
#    </item>
#    <item id="R01670">
#     <name>
#      Таджикский сомони
#     </name>
#     <engname>
#      Tajikistan Ruble
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01670
#     </parentcode>
#    </item>
#    <item id="R01670B">
#     <name>
#      Таджикский рубл
#     </name>
#     <engname>
#      Tajikistan Ruble
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01670
#     </parentcode>
#    </item>
#    <item id="R01700J">
#     <name>
#      Турецкая лира
#     </name>
#     <engname>
#      Turkish Lira
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01700
#     </parentcode>
#    </item>
#    <item id="R01710">
#     <name>
#      Туркменский манат
#     </name>
#     <engname>
#      Turkmenistan Manat
#     </engname>
#     <nominal>
#      10000
#     </nominal>
#     <parentcode>
#      R01710
#     </parentcode>
#    </item>
#    <item id="R01710A">
#     <name>
#      Новый туркменский манат
#     </name>
#     <engname>
#      New Turkmenistan Manat
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01710
#     </parentcode>
#    </item>
#    <item id="R01717">
#     <name>
#      Узбекский сум
#     </name>
#     <engname>
#      Uzbekistan Sum
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01717
#     </parentcode>
#    </item>
#    <item id="R01720">
#     <name>
#      Украинская гривна
#     </name>
#     <engname>
#      Ukrainian Hryvnia
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01720
#     </parentcode>
#    </item>
#    <item id="R01720A">
#     <name>
#      Украинский карбованец
#     </name>
#     <engname>
#      Ukrainian Hryvnia
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01720
#     </parentcode>
#    </item>
#    <item id="R01740">
#     <name>
#      Финляндская марка
#     </name>
#     <engname>
#      Finnish Marka
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01740
#     </parentcode>
#    </item>
#    <item id="R01750">
#     <name>
#      Французский франк
#     </name>
#     <engname>
#      French Franc
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01750
#     </parentcode>
#    </item>
#    <item id="R01760">
#     <name>
#      Чешская крона
#     </name>
#     <engname>
#      Czech Koruna
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01760
#     </parentcode>
#    </item>
#    <item id="R01770">
#     <name>
#      Шведская крона
#     </name>
#     <engname>
#      Swedish Krona
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01770
#     </parentcode>
#    </item>
#    <item id="R01775">
#     <name>
#      Швейцарский франк
#     </name>
#     <engname>
#      Swiss Franc
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01775
#     </parentcode>
#    </item>
#    <item id="R01790">
#     <name>
#      ЭКЮ
#     </name>
#     <engname>
#      ECU
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01790
#     </parentcode>
#    </item>
#    <item id="R01795">
#     <name>
#      Эстонская крона
#     </name>
#     <engname>
#      Estonian Kroon
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01795
#     </parentcode>
#    </item>
#    <item id="R01805">
#     <name>
#      Югославский новый динар
#     </name>
#     <engname>
#      Yugoslavian Dinar
#     </engname>
#     <nominal>
#      1
#     </nominal>
#     <parentcode>
#      R01804
#     </parentcode>
#    </item>
#    <item id="R01810">
#     <name>
#      Южноафриканский рэнд
#     </name>
#     <engname>
#      S.African Rand
#     </engname>
#     <nominal>
#      10
#     </nominal>
#     <parentcode>
#      R01810
#     </parentcode>
#    </item>
#    <item id="R01815">
#     <name>
#      Вон Республики Корея
#     </name>
#     <engname>
#      South Korean Won
#     </engname>
#     <nominal>
#      1000
#     </nominal>
#     <parentcode>
#      R01815
#     </parentcode>
#    </item>
#    <item id="R01820">
#     <name>
#      Японская иена
#     </name>
#     <engname>
#      Japanese Yen
#     </engname>
#     <nominal>
#      100
#     </nominal>
#     <parentcode>
#      R01820
#     </parentcode>
#    </item>
#   </valuta>
#  </body>
# </html>

# %%
soup.find_all('name')
# Out:
# [<name>Австралийский доллар</name>,
#  <name>Австрийский шиллинг</name>,
#  <name>Азербайджанский манат</name>,
#  <name>Фунт стерлингов Соединенного королевства</name>,
#  <name>Ангольская новая кванза</name>,
#  <name>Армянский драм</name>,
#  <name>Белорусский рубль</name>,
#  <name>Бельгийский франк</name>,
#  <name>Болгарский лев</name>,
#  <name>Бразильский реал</name>,
#  <name>Венгерский форинт</name>,
#  <name>Гонконгский доллар</name>,
#  <name>Греческая драхма</name>,
#  <name>Датская крона</name>,
#  <name>Доллар США</name>,
#  <name>Евро</name>,
#  <name>Индийская рупия</name>,
#  <name>Ирландский фунт</name>,
#  <name>Исландская крона</name>,
#  <name>Испанская песета</name>,
#  <name>Итальянская лира</name>,
#  <name>Казахстанский тенге</name>,
#  <name>Канадский доллар</name>,
#  <name>Киргизский сом</name>,
#  <name>Китайский юань</name>,
#  <name>Кувейтский динар</name>,
#  <name>Латвийский лат</name>,
#  <name>Ливанский фунт</name>,
#  <name>Литовский лит</name>,
#  <name>Литовский талон</name>,
#  <name>Молдавский лей</name>,
#  <name>Немецкая марка</name>,
#  <name>Немецкая марка</name>,
#  <name>Нидерландский гульден</name>,
#  <name>Норвежская крона</name>,
#  <name>Польский злотый</name>,
#  <name>Португальский эскудо</name>,
#  <name>Румынский лей</name>,
#  <name>Румынский лей</name>,
#  <name>СДР (специальные права заимствования)</name>,
#  <name>Сингапурский доллар</name>,
#  <name>Суринамский доллар</name>,
#  <name>Таджикский сомони</name>,
#  <name>Таджикский рубл</name>,
#  <name>Турецкая лира</name>,
#  <name>Туркменский манат</name>,
#  <name>Новый туркменский манат</name>,
#  <name>Узбекский сум</name>,
#  <name>Украинская гривна</name>,
#  <name>Украинский карбованец</name>,
#  <name>Финляндская марка</name>,
#  <name>Французский франк</name>,
#  <name>Чешская крона</name>,
#  <name>Шведская крона</name>,
#  <name>Швейцарский франк</name>,
#  <name>ЭКЮ</name>,
#  <name>Эстонская крона</name>,
#  <name>Югославский новый динар</name>,
#  <name>Южноафриканский рэнд</name>,
#  <name>Вон Республики Корея</name>,
#  <name>Японская иена</name>]

# %%
url = "https://seaborn.pydata.org/examples/index.html"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Example gallery — seaborn 0.11.2 documentation</title>
# <link href="../_static/pygments.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/bootstrap-sphinx.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/plot_directive.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/style.css?v=0.11.2" rel="stylesheet" type="text/css"/>
# <script data-url_root="../" id="documentation_options" src="../_static/documentation_options.js"></script>
# <script src="../_static/jquery.js"></script>
# <script src="../_static/underscore.js"></script>
# <script src="../_static/doctools.js"></script>
# <script src="../_static/language_data.js"></script>
# <script src="../_static/copybutton.js"></script>
# <link href="../_static/favicon.ico" rel="shortcut icon"/>
# <link href="../genindex.html" rel="index" title="Index"/>
# <link href="../search.html" rel="search" title="Search"/>
# <link href="anscombes_quartet.html" rel="next" title="Anscombe’s quartet"/>
# <link href="../installing.html" rel="prev" title="Installing and getting started"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <script src="../_static/js/jquery-1.11.0.min.js " type="text/javascript"></script>
# <script src="../_static/js/jquery-fix.js " type="text/javascript"></script>
# <script src="../_static/bootstrap-3.3.7/js/bootstrap.min.js " type="text/javascript"></script>
# <script src="../_static/bootstrap-sphinx.js " type="text/javascript"></script>
# </head><body>
# <div class="navbar navbar-default navbar-fixed-top" id="navbar">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".nav-collapse" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="../index.html"><span><img src="../_static/logo-wide-lightbg.svg"/></span>
# </a>
# <span class="navbar-text navbar-version pull-left"><b>0.11.2</b></span>
# </div>
# <div class="collapse navbar-collapse nav-collapse">
# <ul class="nav navbar-nav">
# <li><a href="#">Gallery</a></li>
# <li><a href="../tutorial.html">Tutorial</a></li>
# <li><a href="../api.html">API</a></li>
# <li class="dropdown globaltoc-container">
# <a data-target="#" data-toggle="dropdown" href="../index.html" id="dLabelGlobalToc" role="button">Site <b class="caret"></b></a>
# <ul aria-labelledby="dLabelGlobalToc" class="dropdown-menu globaltoc" role="menu"><ul class="current">
# <li class="toctree-l1"><a class="reference internal" href="../introduction.html">Introduction</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../whatsnew.html">Release notes</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../installing.html">Installing</a></li>
# <li class="toctree-l1 current"><a class="current reference internal" href="#">Example gallery</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../tutorial.html">Tutorial</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../api.html">API reference</a></li>
# </ul>
# <ul>
# <li class="toctree-l1"><a class="reference internal" href="../citing.html">Citing</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../archive.html">Archive</a></li>
# </ul>
# </ul>
# </li>
# <li class="dropdown">
# <a data-target="#" data-toggle="dropdown" href="#" id="dLabelLocalToc" role="button">Page <b class="caret"></b></a>
# <ul aria-labelledby="dLabelLocalToc" class="dropdown-menu localtoc" role="menu"><ul>
# <li><a class="reference internal" href="#">Example gallery</a></li>
# </ul>
# </ul>
# </li>
# </ul>
# <form action="../search.html" class="navbar-form navbar-right" method="get">
# <div class="form-group">
# <input class="form-control" name="q" placeholder="Search" type="text"/>
# </div>
# <input name="check_keywords" type="hidden" value="yes"/>
# <input name="area" type="hidden" value="default"/>
# </form>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="body col-md-12 content" role="main">
# <style type="text/css">
# .figure {
#     position: relative;
#     float: left;
#     margin: 10px;
#     width: 180px;
#     height: 200px;
# }
#
# .figure img {
#     position: absolute;
#     display: inline;
#     left: 0;
#     width: 170px;
#     height: 170px;
#     opacity:1.0;
#     filter:alpha(opacity=100); /* For IE8 and earlier */
# }
#
# .figure:hover img {
#     -webkit-filter: blur(3px);
#     -moz-filter: blur(3px);
#     -o-filter: blur(3px);
#     -ms-filter: blur(3px);
#     filter: blur(3px);
#     opacity:1.0;
#     filter:alpha(opacity=100); /* For IE8 and earlier */
# }
#
# .figure span {
#     position: absolute;
#     display: inline;
#     left: 0;
#     width: 170px;
#     height: 170px;
#     background: #000;
#     color: #fff;
#     visibility: hidden;
#     opacity: 0;
#     z-index: 100;
# }
#
# .figure p {
#     position: absolute;
#     top: 45%;
#     width: 170px;
#     font-size: 110%;
# }
#
# .figure:hover span {
#     visibility: visible;
#     opacity: .4;
# }
#
# .caption {
#     position: absolute;
#     width: 180px;
#     top: 170px;
#     text-align: center !important;
# }
# </style><div class="section" id="example-gallery">
# <span id="id1"></span><h1>Example gallery<a class="headerlink" href="#example-gallery" title="Permalink to this headline">¶</a></h1>
# <div class="toctree-wrapper compound">
# </div>
# <div class="figure align-center">
# <a href="./anscombes_quartet.html">
# <img src="../_static/anscombes_quartet_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>lmplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./different_scatter_variables.html">
# <img src="../_static/different_scatter_variables_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>scatterplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./errorband_lineplots.html">
# <img src="../_static/errorband_lineplots_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>lineplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./faceted_histogram.html">
# <img src="../_static/faceted_histogram_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>displot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./faceted_lineplot.html">
# <img src="../_static/faceted_lineplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>relplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./grouped_barplot.html">
# <img src="../_static/grouped_barplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>catplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./grouped_boxplot.html">
# <img src="../_static/grouped_boxplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>boxplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./grouped_violinplots.html">
# <img src="../_static/grouped_violinplots_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>violinplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./heat_scatter.html">
# <img src="../_static/heat_scatter_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>relplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./hexbin_marginals.html">
# <img src="../_static/hexbin_marginals_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>jointplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./histogram_stacked.html">
# <img src="../_static/histogram_stacked_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>histplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./horizontal_boxplot.html">
# <img src="../_static/horizontal_boxplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>boxplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./jitter_stripplot.html">
# <img src="../_static/jitter_stripplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>stripplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./joint_histogram.html">
# <img src="../_static/joint_histogram_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>JointGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./joint_kde.html">
# <img src="../_static/joint_kde_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>jointplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./kde_ridgeplot.html">
# <img src="../_static/kde_ridgeplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>FacetGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./large_distributions.html">
# <img src="../_static/large_distributions_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>boxenplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./layered_bivariate_plot.html">
# <img src="../_static/layered_bivariate_plot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>scatterplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./logistic_regression.html">
# <img src="../_static/logistic_regression_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>lmplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./many_facets.html">
# <img src="../_static/many_facets_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>FacetGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./many_pairwise_correlations.html">
# <img src="../_static/many_pairwise_correlations_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>heatmap</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./marginal_ticks.html">
# <img src="../_static/marginal_ticks_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>JointGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./multiple_bivariate_kde.html">
# <img src="../_static/multiple_bivariate_kde_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>kdeplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./multiple_conditional_kde.html">
# <img src="../_static/multiple_conditional_kde_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>displot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./multiple_ecdf.html">
# <img src="../_static/multiple_ecdf_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>displot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./multiple_regression.html">
# <img src="../_static/multiple_regression_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>lmplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./pair_grid_with_kde.html">
# <img src="../_static/pair_grid_with_kde_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>PairGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./paired_pointplots.html">
# <img src="../_static/paired_pointplots_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>PairGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./pairgrid_dotplot.html">
# <img src="../_static/pairgrid_dotplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>PairGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./palette_choices.html">
# <img src="../_static/palette_choices_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>barplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./palette_generation.html">
# <img src="../_static/palette_generation_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>kdeplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./part_whole_bars.html">
# <img src="../_static/part_whole_bars_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>barplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./pointplot_anova.html">
# <img src="../_static/pointplot_anova_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>catplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./radial_facets.html">
# <img src="../_static/radial_facets_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>FacetGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./regression_marginals.html">
# <img src="../_static/regression_marginals_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>jointplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./residplot.html">
# <img src="../_static/residplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>residplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./scatter_bubbles.html">
# <img src="../_static/scatter_bubbles_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>relplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./scatterplot_categorical.html">
# <img src="../_static/scatterplot_categorical_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>swarmplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./scatterplot_matrix.html">
# <img src="../_static/scatterplot_matrix_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>pairplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./scatterplot_sizes.html">
# <img src="../_static/scatterplot_sizes_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>relplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./simple_violinplots.html">
# <img src="../_static/simple_violinplots_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>violinplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./smooth_bivariate_kde.html">
# <img src="../_static/smooth_bivariate_kde_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>JointGrid</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./spreadsheet_heatmap.html">
# <img src="../_static/spreadsheet_heatmap_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>heatmap</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./structured_heatmap.html">
# <img src="../_static/structured_heatmap_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>clustermap</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./three_variable_histogram.html">
# <img src="../_static/three_variable_histogram_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>displot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./timeseries_facets.html">
# <img src="../_static/timeseries_facets_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>relplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./wide_data_lineplot.html">
# <img src="../_static/wide_data_lineplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>lineplot</p>
# </span>
# </a>
# </div><div class="figure align-center">
# <a href="./wide_form_violinplot.html">
# <img src="../_static/wide_form_violinplot_thumb.png?v=0.11.2"/>
# <span class="figure-label">
# <p>violinplot</p>
# </span>
# </a>
# </div><div style="clear: both"></div></div>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="container">
# <p class="pull-right">
# <a href="#">Back to top</a>
# <br/>
# </p>
# <p>
# © Copyright 2012-2021, <a href="https://mwaskom.github.io/">Michael Waskom</a>.
# Created using <a href="https://www.sphinx-doc.org/">Sphinx</a> 3.3.1.<br/>
# </p>
# </div>
# </footer>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Example gallery — seaborn 0.11.2 documentation
#   </title>
#   <link href="../_static/pygments.css" rel="stylesheet" type="text/css"/>
#   <link href="../_static/bootstrap-sphinx.css" rel="stylesheet" type="text/css"/>
#   <link href="../_static/plot_directive.css" rel="stylesheet" type="text/css"/>
#   <link href="../_static/style.css?v=0.11.2" rel="stylesheet" type="text/css"/>
#   <script data-url_root="../" id="documentation_options" src="../_static/documentation_options.js">
#   </script>
#   <script src="../_static/jquery.js">
#   </script>
#   <script src="../_static/underscore.js">
#   </script>
#   <script src="../_static/doctools.js">
#   </script>
#   <script src="../_static/language_data.js">
#   </script>
#   <script src="../_static/copybutton.js">
#   </script>
#   <link href="../_static/favicon.ico" rel="shortcut icon"/>
#   <link href="../genindex.html" rel="index" title="Index"/>
#   <link href="../search.html" rel="search" title="Search"/>
#   <link href="anscombes_quartet.html" rel="next" title="Anscombe’s quartet"/>
#   <link href="../installing.html" rel="prev" title="Installing and getting started"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <script src="../_static/js/jquery-1.11.0.min.js " type="text/javascript">
#   </script>
#   <script src="../_static/js/jquery-fix.js " type="text/javascript">
#   </script>
#   <script src="../_static/bootstrap-3.3.7/js/bootstrap.min.js " type="text/javascript">
#   </script>
#   <script src="../_static/bootstrap-sphinx.js " type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="navbar navbar-default navbar-fixed-top" id="navbar">
#    <div class="container">
#     <div class="navbar-header">
#      <button class="navbar-toggle" data-target=".nav-collapse" data-toggle="collapse" type="button">
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="../index.html">
#       <span>
#        <img src="../_static/logo-wide-lightbg.svg"/>
#       </span>
#      </a>
#      <span class="navbar-text navbar-version pull-left">
#       <b>
#        0.11.2
#       </b>
#      </span>
#     </div>
#     <div class="collapse navbar-collapse nav-collapse">
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="#">
#         Gallery
#        </a>
#       </li>
#       <li>
#        <a href="../tutorial.html">
#         Tutorial
#        </a>
#       </li>
#       <li>
#        <a href="../api.html">
#         API
#        </a>
#       </li>
#       <li class="dropdown globaltoc-container">
#        <a data-target="#" data-toggle="dropdown" href="../index.html" id="dLabelGlobalToc" role="button">
#         Site
#         <b class="caret">
#         </b>
#        </a>
#        <ul aria-labelledby="dLabelGlobalToc" class="dropdown-menu globaltoc" role="menu">
#         <ul class="current">
#          <li class="toctree-l1">
#           <a class="reference internal" href="../introduction.html">
#            Introduction
#           </a>
#          </li>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../whatsnew.html">
#            Release notes
#           </a>
#          </li>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../installing.html">
#            Installing
#           </a>
#          </li>
#          <li class="toctree-l1 current">
#           <a class="current reference internal" href="#">
#            Example gallery
#           </a>
#          </li>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../tutorial.html">
#            Tutorial
#           </a>
#          </li>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../api.html">
#            API reference
#           </a>
#          </li>
#         </ul>
#         <ul>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../citing.html">
#            Citing
#           </a>
#          </li>
#          <li class="toctree-l1">
#           <a class="reference internal" href="../archive.html">
#            Archive
#           </a>
#          </li>
#         </ul>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a data-target="#" data-toggle="dropdown" href="#" id="dLabelLocalToc" role="button">
#         Page
#         <b class="caret">
#         </b>
#        </a>
#        <ul aria-labelledby="dLabelLocalToc" class="dropdown-menu localtoc" role="menu">
#         <ul>
#          <li>
#           <a class="reference internal" href="#">
#            Example gallery
#           </a>
#          </li>
#         </ul>
#        </ul>
#       </li>
#      </ul>
#      <form action="../search.html" class="navbar-form navbar-right" method="get">
#       <div class="form-group">
#        <input class="form-control" name="q" placeholder="Search" type="text"/>
#       </div>
#       <input name="check_keywords" type="hidden" value="yes"/>
#       <input name="area" type="hidden" value="default"/>
#      </form>
#     </div>
#    </div>
#   </div>
#   <div class="container">
#    <div class="row">
#     <div class="body col-md-12 content" role="main">
#      <style type="text/css">
#       .figure {
#     position: relative;
#     float: left;
#     margin: 10px;
#     width: 180px;
#     height: 200px;
# }
#
# .figure img {
#     position: absolute;
#     display: inline;
#     left: 0;
#     width: 170px;
#     height: 170px;
#     opacity:1.0;
#     filter:alpha(opacity=100); /* For IE8 and earlier */
# }
#
# .figure:hover img {
#     -webkit-filter: blur(3px);
#     -moz-filter: blur(3px);
#     -o-filter: blur(3px);
#     -ms-filter: blur(3px);
#     filter: blur(3px);
#     opacity:1.0;
#     filter:alpha(opacity=100); /* For IE8 and earlier */
# }
#
# .figure span {
#     position: absolute;
#     display: inline;
#     left: 0;
#     width: 170px;
#     height: 170px;
#     background: #000;
#     color: #fff;
#     visibility: hidden;
#     opacity: 0;
#     z-index: 100;
# }
#
# .figure p {
#     position: absolute;
#     top: 45%;
#     width: 170px;
#     font-size: 110%;
# }
#
# .figure:hover span {
#     visibility: visible;
#     opacity: .4;
# }
#
# .caption {
#     position: absolute;
#     width: 180px;
#     top: 170px;
#     text-align: center !important;
# }
#      </style>
#      <div class="section" id="example-gallery">
#       <span id="id1">
#       </span>
#       <h1>
#        Example gallery
#        <a class="headerlink" href="#example-gallery" title="Permalink to this headline">
#         ¶
#        </a>
#       </h1>
#       <div class="toctree-wrapper compound">
#       </div>
#       <div class="figure align-center">
#        <a href="./anscombes_quartet.html">
#         <img src="../_static/anscombes_quartet_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           lmplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./different_scatter_variables.html">
#         <img src="../_static/different_scatter_variables_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           scatterplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./errorband_lineplots.html">
#         <img src="../_static/errorband_lineplots_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           lineplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./faceted_histogram.html">
#         <img src="../_static/faceted_histogram_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           displot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./faceted_lineplot.html">
#         <img src="../_static/faceted_lineplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           relplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./grouped_barplot.html">
#         <img src="../_static/grouped_barplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           catplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./grouped_boxplot.html">
#         <img src="../_static/grouped_boxplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           boxplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./grouped_violinplots.html">
#         <img src="../_static/grouped_violinplots_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           violinplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./heat_scatter.html">
#         <img src="../_static/heat_scatter_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           relplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./hexbin_marginals.html">
#         <img src="../_static/hexbin_marginals_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           jointplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./histogram_stacked.html">
#         <img src="../_static/histogram_stacked_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           histplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./horizontal_boxplot.html">
#         <img src="../_static/horizontal_boxplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           boxplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./jitter_stripplot.html">
#         <img src="../_static/jitter_stripplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           stripplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./joint_histogram.html">
#         <img src="../_static/joint_histogram_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           JointGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./joint_kde.html">
#         <img src="../_static/joint_kde_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           jointplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./kde_ridgeplot.html">
#         <img src="../_static/kde_ridgeplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           FacetGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./large_distributions.html">
#         <img src="../_static/large_distributions_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           boxenplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./layered_bivariate_plot.html">
#         <img src="../_static/layered_bivariate_plot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           scatterplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./logistic_regression.html">
#         <img src="../_static/logistic_regression_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           lmplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./many_facets.html">
#         <img src="../_static/many_facets_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           FacetGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./many_pairwise_correlations.html">
#         <img src="../_static/many_pairwise_correlations_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           heatmap
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./marginal_ticks.html">
#         <img src="../_static/marginal_ticks_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           JointGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./multiple_bivariate_kde.html">
#         <img src="../_static/multiple_bivariate_kde_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           kdeplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./multiple_conditional_kde.html">
#         <img src="../_static/multiple_conditional_kde_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           displot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./multiple_ecdf.html">
#         <img src="../_static/multiple_ecdf_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           displot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./multiple_regression.html">
#         <img src="../_static/multiple_regression_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           lmplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./pair_grid_with_kde.html">
#         <img src="../_static/pair_grid_with_kde_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           PairGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./paired_pointplots.html">
#         <img src="../_static/paired_pointplots_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           PairGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./pairgrid_dotplot.html">
#         <img src="../_static/pairgrid_dotplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           PairGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./palette_choices.html">
#         <img src="../_static/palette_choices_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           barplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./palette_generation.html">
#         <img src="../_static/palette_generation_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           kdeplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./part_whole_bars.html">
#         <img src="../_static/part_whole_bars_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           barplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./pointplot_anova.html">
#         <img src="../_static/pointplot_anova_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           catplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./radial_facets.html">
#         <img src="../_static/radial_facets_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           FacetGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./regression_marginals.html">
#         <img src="../_static/regression_marginals_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           jointplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./residplot.html">
#         <img src="../_static/residplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           residplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./scatter_bubbles.html">
#         <img src="../_static/scatter_bubbles_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           relplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./scatterplot_categorical.html">
#         <img src="../_static/scatterplot_categorical_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           swarmplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./scatterplot_matrix.html">
#         <img src="../_static/scatterplot_matrix_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           pairplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./scatterplot_sizes.html">
#         <img src="../_static/scatterplot_sizes_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           relplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./simple_violinplots.html">
#         <img src="../_static/simple_violinplots_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           violinplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./smooth_bivariate_kde.html">
#         <img src="../_static/smooth_bivariate_kde_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           JointGrid
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./spreadsheet_heatmap.html">
#         <img src="../_static/spreadsheet_heatmap_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           heatmap
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./structured_heatmap.html">
#         <img src="../_static/structured_heatmap_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           clustermap
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./three_variable_histogram.html">
#         <img src="../_static/three_variable_histogram_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           displot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./timeseries_facets.html">
#         <img src="../_static/timeseries_facets_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           relplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./wide_data_lineplot.html">
#         <img src="../_static/wide_data_lineplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           lineplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div class="figure align-center">
#        <a href="./wide_form_violinplot.html">
#         <img src="../_static/wide_form_violinplot_thumb.png?v=0.11.2"/>
#         <span class="figure-label">
#          <p>
#           violinplot
#          </p>
#         </span>
#        </a>
#       </div>
#       <div style="clear: both">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="footer">
#    <div class="container">
#     <p class="pull-right">
#      <a href="#">
#       Back to top
#      </a>
#      <br/>
#     </p>
#     <p>
#      © Copyright 2012-2021,
#      <a href="https://mwaskom.github.io/">
#       Michael Waskom
#      </a>
#      .
# Created using
#      <a href="https://www.sphinx-doc.org/">
#       Sphinx
#      </a>
#      3.3.1.
#      <br/>
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %%
lst = soup.find_all('p')
lst
# Out:
# [<p>lmplot</p>,
#  <p>scatterplot</p>,
#  <p>lineplot</p>,
#  <p>displot</p>,
#  <p>relplot</p>,
#  <p>catplot</p>,
#  <p>boxplot</p>,
#  <p>violinplot</p>,
#  <p>relplot</p>,
#  <p>jointplot</p>,
#  <p>histplot</p>,
#  <p>boxplot</p>,
#  <p>stripplot</p>,
#  <p>JointGrid</p>,
#  <p>jointplot</p>,
#  <p>FacetGrid</p>,
#  <p>boxenplot</p>,
#  <p>scatterplot</p>,
#  <p>lmplot</p>,
#  <p>FacetGrid</p>,
#  <p>heatmap</p>,
#  <p>JointGrid</p>,
#  <p>kdeplot</p>,
#  <p>displot</p>,
#  <p>displot</p>,
#  <p>lmplot</p>,
#  <p>PairGrid</p>,
#  <p>PairGrid</p>,
#  <p>PairGrid</p>,
#  <p>barplot</p>,
#  <p>kdeplot</p>,
#  <p>barplot</p>,
#  <p>catplot</p>,
#  <p>FacetGrid</p>,
#  <p>jointplot</p>,
#  <p>residplot</p>,
#  <p>relplot</p>,
#  <p>swarmplot</p>,
#  <p>pairplot</p>,
#  <p>relplot</p>,
#  <p>violinplot</p>,
#  <p>JointGrid</p>,
#  <p>heatmap</p>,
#  <p>clustermap</p>,
#  <p>displot</p>,
#  <p>relplot</p>,
#  <p>lineplot</p>,
#  <p>violinplot</p>,
#  <p class="pull-right">
#  <a href="#">Back to top</a>
#  <br/>
#  </p>,
#  <p>
#  © Copyright 2012-2021, <a href="https://mwaskom.github.io/">Michael Waskom</a>.
#  Created using <a href="https://www.sphinx-doc.org/">Sphinx</a> 3.3.1.<br/>
#  </p>]

# %%
def clean_item(item):
    position = item.find('</p')
    return item[3:position]

print(clean_item('<p>lineplot</p>,'))
# Out:
# lineplot

# %%
for item in lst:
    print(clean_item(str(item)))
# Out:
# lmplot
# scatterplot
# lineplot
# displot
# relplot
# catplot
# boxplot
# violinplot
# relplot
# jointplot
# histplot
# boxplot
# stripplot
# JointGrid
# jointplot
# FacetGrid
# boxenplot
# scatterplot
# lmplot
# FacetGrid
# heatmap
# JointGrid
# kdeplot
# displot
# displot
# lmplot
# PairGrid
# PairGrid
# PairGrid
# barplot
# kdeplot
# barplot
# catplot
# FacetGrid
# jointplot
# residplot
# relplot
# swarmplot
# pairplot
# relplot
# violinplot
# JointGrid
# heatmap
# clustermap
# displot
# relplot
# lineplot
# violinplot
# class="pull-right">
# <a href="#">Back to top</a>
# <br/>
#
#
# © Copyright 2012-2021, <a href="https://mwaskom.github.io/">Michael Waskom</a>.
# Created using <a href="https://www.sphinx-doc.org/">Sphinx</a> 3.3.1.<br/>

# %%
lst[:-2]
# Out:
# [<p>lmplot</p>,
#  <p>scatterplot</p>,
#  <p>lineplot</p>,
#  <p>displot</p>,
#  <p>relplot</p>,
#  <p>catplot</p>,
#  <p>boxplot</p>,
#  <p>violinplot</p>,
#  <p>relplot</p>,
#  <p>jointplot</p>,
#  <p>histplot</p>,
#  <p>boxplot</p>,
#  <p>stripplot</p>,
#  <p>JointGrid</p>,
#  <p>jointplot</p>,
#  <p>FacetGrid</p>,
#  <p>boxenplot</p>,
#  <p>scatterplot</p>,
#  <p>lmplot</p>,
#  <p>FacetGrid</p>,
#  <p>heatmap</p>,
#  <p>JointGrid</p>,
#  <p>kdeplot</p>,
#  <p>displot</p>,
#  <p>displot</p>,
#  <p>lmplot</p>,
#  <p>PairGrid</p>,
#  <p>PairGrid</p>,
#  <p>PairGrid</p>,
#  <p>barplot</p>,
#  <p>kdeplot</p>,
#  <p>barplot</p>,
#  <p>catplot</p>,
#  <p>FacetGrid</p>,
#  <p>jointplot</p>,
#  <p>residplot</p>,
#  <p>relplot</p>,
#  <p>swarmplot</p>,
#  <p>pairplot</p>,
#  <p>relplot</p>,
#  <p>violinplot</p>,
#  <p>JointGrid</p>,
#  <p>heatmap</p>,
#  <p>clustermap</p>,
#  <p>displot</p>,
#  <p>relplot</p>,
#  <p>lineplot</p>,
#  <p>violinplot</p>]

# %%
for item in lst[:-2]:
    print(clean_item(str(item)))
# Out:
# lmplot
# scatterplot
# lineplot
# displot
# relplot
# catplot
# boxplot
# violinplot
# relplot
# jointplot
# histplot
# boxplot
# stripplot
# JointGrid
# jointplot
# FacetGrid
# boxenplot
# scatterplot
# lmplot
# FacetGrid
# heatmap
# JointGrid
# kdeplot
# displot
# displot
# lmplot
# PairGrid
# PairGrid
# PairGrid
# barplot
# kdeplot
# barplot
# catplot
# FacetGrid
# jointplot
# residplot
# relplot
# swarmplot
# pairplot
# relplot
# violinplot
# JointGrid
# heatmap
# clustermap
# displot
# relplot
# lineplot
# violinplot
