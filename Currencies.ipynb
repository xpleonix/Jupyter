# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_val.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><Valuta name="Foreign Currency Market Lib"><Item ID="R01010"><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><EngName>Australian Dollar</EngName><Nominal>1</Nominal><ParentCode>R01010    </ParentCode></Item><Item ID="R01015"><Name>\xc0\xe2\xf1\xf2\xf0\xe8\xe9\xf1\xea\xe8\xe9 \xf8\xe8\xeb\xeb\xe8\xed\xe3</Name><EngName>Austrian Shilling</EngName><Nominal>1000</Nominal><ParentCode>R01015    </ParentCode></Item><Item ID="R01020A"><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><EngName>Azerbaijan Manat</EngName><Nominal>1</Nominal><ParentCode>R01020    </ParentCode></Item><Item ID="R01035"><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><EngName>British Pound Sterling</EngName><Nominal>1</Nominal><ParentCode>R01035    </ParentCode></Item><Item ID="R01040F"><Name>\xc0\xed\xe3\xee\xeb\xfc\xf1\xea\xe0\xff \xed\xee\xe2\xe0\xff \xea\xe2\xe0\xed\xe7\xe0</Name><EngName>Angolan new Kwanza</EngName><Nominal>100000</Nominal><ParentCode>R01040    </ParentCode></Item><Item ID="R01060"><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xe9 \xe4\xf0\xe0\xec</Name><EngName>Armenia Dram</EngName><Nominal>1000</Nominal><ParentCode>R01060    </ParentCode></Item><Item ID="R01090B"><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><EngName>Belarussian Ruble</EngName><Nominal>1</Nominal><ParentCode>R01090    </ParentCode></Item><Item ID="R01095"><Name>\xc1\xe5\xeb\xfc\xe3\xe8\xe9\xf1\xea\xe8\xe9 \xf4\xf0\xe0\xed\xea</Name><EngName>Belgium Franc</EngName><Nominal>1000</Nominal><ParentCode>R01095    </ParentCode></Item><Item ID="R01100"><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><EngName>Bulgarian lev</EngName><Nominal>1</Nominal><ParentCode>R01100    </ParentCode></Item><Item ID="R01115"><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><EngName>Brazil Real</EngName><Nominal>1</Nominal><ParentCode>R01115    </ParentCode></Item><Item ID="R01135"><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xe9 \xf4\xee\xf0\xe8\xed\xf2</Name><EngName>Hungarian Forint</EngName><Nominal>100</Nominal><ParentCode>R01135    </ParentCode></Item><Item ID="R01200"><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><EngName>Hong Kong Dollar</EngName><Nominal>10</Nominal><ParentCode>R01200    </ParentCode></Item><Item ID="R01205"><Name>\xc3\xf0\xe5\xf7\xe5\xf1\xea\xe0\xff \xe4\xf0\xe0\xf5\xec\xe0</Name><EngName>Greek Drachma</EngName><Nominal>10000</Nominal><ParentCode>R01205    </ParentCode></Item><Item ID="R01215"><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><EngName>Danish Krone</EngName><Nominal>10</Nominal><ParentCode>R01215    </ParentCode></Item><Item ID="R01235"><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><EngName>US Dollar</EngName><Nominal>1</Nominal><ParentCode>R01235    </ParentCode></Item><Item ID="R01239"><Name>\xc5\xe2\xf0\xee</Name><EngName>Euro</EngName><Nominal>1</Nominal><ParentCode>R01239    </ParentCode></Item><Item ID="R01270"><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe0\xff \xf0\xf3\xef\xe8\xff</Name><EngName>Indian Rupee</EngName><Nominal>100</Nominal><ParentCode>R01270    </ParentCode></Item><Item ID="R01305"><Name>\xc8\xf0\xeb\xe0\xed\xe4\xf1\xea\xe8\xe9 \xf4\xf3\xed\xf2</Name><EngName>Irish Pound</EngName><Nominal>100</Nominal><ParentCode>R01305    </ParentCode></Item><Item ID="R01310"><Name>\xc8\xf1\xeb\xe0\xed\xe4\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><EngName>Iceland Krona</EngName><Nominal>10000</Nominal><ParentCode>R01310    </ParentCode></Item><Item ID="R01315"><Name>\xc8\xf1\xef\xe0\xed\xf1\xea\xe0\xff \xef\xe5\xf1\xe5\xf2\xe0</Name><EngName>Spanish Peseta</EngName><Nominal>10000</Nominal><ParentCode>R01315    </ParentCode></Item><Item ID="R01325"><Name>\xc8\xf2\xe0\xeb\xfc\xff\xed\xf1\xe ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'Valuta': {'@name': 'Foreign Currency Market Lib',
#   'Item': [{'@ID': 'R01010',
#     'Name': 'Австралийский доллар',
#     'EngName': 'Australian Dollar',
#     'Nominal': '1',
#     'ParentCode': 'R01010'},
#    {'@ID': 'R01015',
#     'Name': 'Австрийский шиллинг',
#     'EngName': 'Austrian Shilling',
#     'Nominal': '1000',
#     'ParentCode': 'R01015'},
#    {'@ID': 'R01020A',
#     'Name': 'Азербайджанский манат',
#     'EngName': 'Azerbaijan Manat',
#     'Nominal': '1',
#     'ParentCode': 'R01020'},
#    {'@ID': 'R01035',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'EngName': 'British Pound Sterling',
#     'Nominal': '1',
#     'ParentCode': 'R01035'},
#    {'@ID': 'R01040F',
#     'Name': 'Ангольская новая кванза',
#     'EngName': 'Angolan new Kwanza',
#     'Nominal': '100000',
#     'ParentCode': 'R01040'},
#    {'@ID': 'R01060',
#     'Name': 'Армянский драм',
#     'EngName': 'Armenia Dram',
#     'Nominal': '1000',
#     'ParentCode': 'R01060'},
#    {'@ID': 'R01090B',
#     'Name': 'Белорусский рубль',
#     'EngName': 'Belarussian Ruble',
#     'Nominal': '1',
#     'ParentCode': 'R01090'},
#    {'@ID': 'R01095',
#     'Name': 'Бельгийский франк',
#     'EngName': 'Belgium Franc',
#     'Nominal': '1000',
#     'ParentCode': 'R01095'},
#    {'@ID': 'R01100',
#     'Name': 'Болгарский лев',
#     'EngName': 'Bulgarian lev',
#     'Nominal': '1',
#     'ParentCode': 'R01100'},
#    {'@ID': 'R01115',
#     'Name': 'Бразильский реал',
#     'EngName': 'Brazil Real',
#     'Nominal': '1',
#     'ParentCode': 'R01115'},
#    {'@ID': 'R01135',
#     'Name': 'Венгерский форинт',
#     'EngName': 'Hungarian Forint',
#     'Nominal': '100',
#     'ParentCode': 'R01135'},
#    {'@ID': 'R01200',
#     'Name': 'Гонконгский доллар',
#     'EngName': 'Hong Kong Dollar',
#     'Nominal': '10',
#     'ParentCode': 'R01200'},
#    {'@ID': 'R01205',
#     'Name': 'Греческая драхма',
#     'EngName': 'Greek Drachma',
#     'Nominal': '10000',
#     'ParentCode': 'R01205'},
#    {'@ID': 'R01215',
#     'Name': 'Датская крона',
#     'EngName': 'Danish Krone',
#     'Nominal': '10',
#     'ParentCode': 'R01215'},
#    {'@ID': 'R01235',
#     'Name': 'Доллар США',
#     'EngName': 'US Dollar',
#     'Nominal': '1',
#     'ParentCode': 'R01235'},
#    {'@ID': 'R01239',
#     'Name': 'Евро',
#     'EngName': 'Euro',
#     'Nominal': '1',
#     'ParentCode': 'R01239'},
#    {'@ID': 'R01270',
#     'Name': 'Индийская рупия',
#     'EngName': 'Indian Rupee',
#     'Nominal': '100',
#     'ParentCode': 'R01270'},
#    {'@ID': 'R01305',
#     'Name': 'Ирландский фунт',
#     'EngName': 'Irish Pound',
#     'Nominal': '100',
#     'ParentCode': 'R01305'},
#    {'@ID': 'R01310',
#     'Name': 'Исландская крона',
#     'EngName': 'Iceland Krona',
#     'Nominal': '10000',
#     'ParentCode': 'R01310'},
#    {'@ID': 'R01315',
#     'Name': 'Испанская песета',
#     'EngName': 'Spanish Peseta',
#     'Nominal': '10000',
#     'ParentCode': 'R01315'},
#    {'@ID': 'R01325',
#     'Name': 'Итальянская лира',
#     'EngName': 'Italian Lira',
#     'Nominal': '100000',
#     'ParentCode': 'R01325'},
#    {'@ID': 'R01335',
#     'Name': 'Казахстанский тенге',
#     'EngName': 'Kazakhstan Tenge',
#     'Nominal': '100',
#     'ParentCode': 'R01335'},
#    {'@ID': 'R01350',
#     'Name': 'Канадский доллар',
#     'EngName': 'Canadian Dollar',
#     'Nominal': '1',
#     'ParentCode': 'R01350'},
#    {'@ID': 'R01370',
#     'Name': 'Киргизский сом',
#     'EngName': 'Kyrgyzstan Som',
#     'Nominal': '100',
#     'ParentCode': 'R01370'},
#    {'@ID': 'R01375',
#     'Name': 'Китайский юань',
#     'EngName': 'China Yuan',
#     'Nominal': '10',
#     'ParentCode': 'R01375'},
#    {'@ID': 'R01390',
#     'Name': 'Кувейтский динар',
#     'EngName': 'Kuwaiti Dinar',
#     'Nominal': '10',
#     'ParentCode': 'R01390'},
#    {'@ID': 'R01405',
#     'Name': 'Латвийский лат',
#     'EngName': 'Latvian Lat',
#     'Nominal': '1',
#     'ParentCode': 'R01405'},
#    {'@ID': 'R01420',
#     'Name': 'Ливанский фунт',
#     'EngName': 'Lebanese Pound',
#     'Nominal': '100000',
#     'ParentCode': 'R01420'},
#    {'@ID': 'R01435',
#     'Name': 'Литовский лит',
#     'EngName': 'Lithuanian Lita',
#     'Nominal': '1',
#     'ParentCode': 'R01435'},
#    {'@ID': 'R01436',
#     'Name': 'Литовский талон',
#     'EngName': 'Lithuanian talon',
#     'Nominal': '1',
#     'ParentCode': 'R01435'},
#    {'@ID': 'R01500',
#     'Name': 'Молдавский лей',
#     'EngName': 'Moldova Lei',
#     'Nominal': '10',
#     'ParentCode': 'R01500'},
#    {'@ID': 'R01510',
#     'Name': 'Немецкая марка',
#     'EngName': 'Deutsche Mark',
#     'Nominal': '1',
#     'ParentCode': 'R01510'},
#    {'@ID': 'R01510A',
#     'Name': 'Немецкая марка',
#     'EngName': 'Deutsche Mark',
#     'Nominal': '100',
#     'ParentCode': 'R01510'},
#    {'@ID': 'R01523',
#     'Name': 'Нидерландский гульден',
#     'EngName': 'Netherlands Gulden',
#     'Nominal': '100',
#     'ParentCode': 'R01523'},
#    {'@ID': 'R01535',
#     'Name': 'Норвежская крона',
#     'EngName': 'Norwegian Krone',
#     'Nominal': '10',
#     'ParentCode': 'R01535'},
#    {'@ID': 'R01565',
#     'Name': 'Польский злотый',
#     'EngName': 'Polish Zloty',
#     'Nominal': '1',
#     'ParentCode': 'R01565'},
#    {'@ID': 'R01570',
#     'Name': 'Португальский эскудо',
#     'EngName': 'Portuguese Escudo',
#     'Nominal': '10000',
#     'ParentCode': 'R01570'},
#    {'@ID': 'R01585',
#     'Name': 'Румынский лей',
#     'EngName': 'Romanian Leu',
#     'Nominal': '10000',
#     'ParentCode': 'R01585'},
#    {'@ID': 'R01585F',
#     'Name': 'Румынский лей',
#     'EngName': 'Romanian Leu',
#     'Nominal': '10',
#     'ParentCode': 'R01585'},
#    {'@ID': 'R01589',
#     'Name': 'СДР (специальные права заимствования)',
#     'EngName': 'SDR',
#     'Nominal': '1',
#     'ParentCode': 'R01589'},
#    {'@ID': 'R01625',
#     'Name': 'Сингапурский доллар',
#     'EngName': 'Singapore Dollar',
#     'Nominal': '1',
#     'ParentCode': 'R01625'},
#    {'@ID': 'R01665A',
#     'Name': 'Суринамский доллар',
#     'EngName': 'Surinam Dollar',
#     'Nominal': '1',
#     'ParentCode': 'R01665'},
#    {'@ID': 'R01670',
#     'Name': 'Таджикский сомони',
#     'EngName': 'Tajikistan Ruble',
#     'Nominal': '10',
#     'ParentCode': 'R01670'},
#    {'@ID': 'R01670B',
#     'Name': 'Таджикский рубл',
#     'EngName': 'Tajikistan Ruble',
#     'Nominal': '10',
#     'ParentCode': 'R01670'},
#    {'@ID': 'R01700J',
#     'Name': 'Турецкая лира',
#     'EngName': 'Turkish Lira',
#     'Nominal': '1',
#     'ParentCode': 'R01700'},
#    {'@ID': 'R01710',
#     'Name': 'Туркменский манат',
#     'EngName': 'Turkmenistan Manat',
#     'Nominal': '10000',
#     'ParentCode': 'R01710'},
#    {'@ID': 'R01710A',
#     'Name': 'Новый туркменский манат',
#     'EngName': 'New Turkmenistan Manat',
#     'Nominal': '1',
#     'ParentCode': 'R01710'},
#    {'@ID': 'R01717',
#     'Name': 'Узбекский сум',
#     'EngName': 'Uzbekistan Sum',
#     'Nominal': '1000',
#     'ParentCode': 'R01717'},
#    {'@ID': 'R01720',
#     'Name': 'Украинская гривна',
#     'EngName': 'Ukrainian Hryvnia',
#     'Nominal': '10',
#     'ParentCode': 'R01720'},
#    {'@ID': 'R01720A',
#     'Name': 'Украинский карбованец',
#     'EngName': 'Ukrainian Hryvnia',
#     'Nominal': '1',
#     'ParentCode': 'R01720'},
#    {'@ID': 'R01740',
#     'Name': 'Финляндская марка',
#     'EngName': 'Finnish Marka',
#     'Nominal': '100',
#     'ParentCode': 'R01740'},
#    {'@ID': 'R01750',
#     'Name': 'Французский франк',
#     'EngName': 'French Franc',
#     'Nominal': '1000',
#     'ParentCode': 'R01750'},
#    {'@ID': 'R01760',
#     'Name': 'Чешская крона',
#     'EngName': 'Czech Koruna',
#     'Nominal': '10',
#     'ParentCode': 'R01760'},
#    {'@ID': 'R01770',
#     'Name': 'Шведская крона',
#     'EngName': 'Swedish Krona',
#     'Nominal': '10',
#     'ParentCode': 'R01770'},
#    {'@ID': 'R01775',
#     'Name': 'Швейцарский франк',
#     'EngName': 'Swiss Franc',
#     'Nominal': '1',
#     'ParentCode': 'R01775'},
#    {'@ID': 'R01790',
#     'Name': 'ЭКЮ',
#     'EngName': 'ECU',
#     'Nominal': '1',
#     'ParentCode': 'R01790'},
#    {'@ID': 'R01795',
#     'Name': 'Эстонская крона',
#     'EngName': 'Estonian Kroon',
#     'Nominal': '10',
#     'ParentCode': 'R01795'},
#    {'@ID': 'R01805',
#     'Name': 'Югославский новый динар',
#     'EngName': 'Yugoslavian Dinar',
#     'Nominal': '1',
#     'ParentCode': 'R01804'},
#    {'@ID': 'R01810',
#     'Name': 'Южноафриканский рэнд',
#     'EngName': 'S.African Rand',
#     'Nominal': '10',
#     'ParentCode': 'R01810'},
#    {'@ID': 'R01815',
#     'Name': 'Вон Республики Корея',
#     'EngName': 'South Korean Won',
#     'Nominal': '1000',
#     'ParentCode': 'R01815'},
#    {'@ID': 'R01820',
#     'Name': 'Японская иена',
#     'EngName': 'Japanese Yen',
#     'Nominal': '100',
#     'ParentCode': 'R01820'}]}}

# %%
items = []
for item in data['Valuta']['Item']:
    items.append(item)
items
# Out:
# [{'@ID': 'R01010',
#   'Name': 'Австралийский доллар',
#   'EngName': 'Australian Dollar',
#   'Nominal': '1',
#   'ParentCode': 'R01010'},
#  {'@ID': 'R01015',
#   'Name': 'Австрийский шиллинг',
#   'EngName': 'Austrian Shilling',
#   'Nominal': '1000',
#   'ParentCode': 'R01015'},
#  {'@ID': 'R01020A',
#   'Name': 'Азербайджанский манат',
#   'EngName': 'Azerbaijan Manat',
#   'Nominal': '1',
#   'ParentCode': 'R01020'},
#  {'@ID': 'R01035',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'EngName': 'British Pound Sterling',
#   'Nominal': '1',
#   'ParentCode': 'R01035'},
#  {'@ID': 'R01040F',
#   'Name': 'Ангольская новая кванза',
#   'EngName': 'Angolan new Kwanza',
#   'Nominal': '100000',
#   'ParentCode': 'R01040'},
#  {'@ID': 'R01060',
#   'Name': 'Армянский драм',
#   'EngName': 'Armenia Dram',
#   'Nominal': '1000',
#   'ParentCode': 'R01060'},
#  {'@ID': 'R01090B',
#   'Name': 'Белорусский рубль',
#   'EngName': 'Belarussian Ruble',
#   'Nominal': '1',
#   'ParentCode': 'R01090'},
#  {'@ID': 'R01095',
#   'Name': 'Бельгийский франк',
#   'EngName': 'Belgium Franc',
#   'Nominal': '1000',
#   'ParentCode': 'R01095'},
#  {'@ID': 'R01100',
#   'Name': 'Болгарский лев',
#   'EngName': 'Bulgarian lev',
#   'Nominal': '1',
#   'ParentCode': 'R01100'},
#  {'@ID': 'R01115',
#   'Name': 'Бразильский реал',
#   'EngName': 'Brazil Real',
#   'Nominal': '1',
#   'ParentCode': 'R01115'},
#  {'@ID': 'R01135',
#   'Name': 'Венгерский форинт',
#   'EngName': 'Hungarian Forint',
#   'Nominal': '100',
#   'ParentCode': 'R01135'},
#  {'@ID': 'R01200',
#   'Name': 'Гонконгский доллар',
#   'EngName': 'Hong Kong Dollar',
#   'Nominal': '10',
#   'ParentCode': 'R01200'},
#  {'@ID': 'R01205',
#   'Name': 'Греческая драхма',
#   'EngName': 'Greek Drachma',
#   'Nominal': '10000',
#   'ParentCode': 'R01205'},
#  {'@ID': 'R01215',
#   'Name': 'Датская крона',
#   'EngName': 'Danish Krone',
#   'Nominal': '10',
#   'ParentCode': 'R01215'},
#  {'@ID': 'R01235',
#   'Name': 'Доллар США',
#   'EngName': 'US Dollar',
#   'Nominal': '1',
#   'ParentCode': 'R01235'},
#  {'@ID': 'R01239',
#   'Name': 'Евро',
#   'EngName': 'Euro',
#   'Nominal': '1',
#   'ParentCode': 'R01239'},
#  {'@ID': 'R01270',
#   'Name': 'Индийская рупия',
#   'EngName': 'Indian Rupee',
#   'Nominal': '100',
#   'ParentCode': 'R01270'},
#  {'@ID': 'R01305',
#   'Name': 'Ирландский фунт',
#   'EngName': 'Irish Pound',
#   'Nominal': '100',
#   'ParentCode': 'R01305'},
#  {'@ID': 'R01310',
#   'Name': 'Исландская крона',
#   'EngName': 'Iceland Krona',
#   'Nominal': '10000',
#   'ParentCode': 'R01310'},
#  {'@ID': 'R01315',
#   'Name': 'Испанская песета',
#   'EngName': 'Spanish Peseta',
#   'Nominal': '10000',
#   'ParentCode': 'R01315'},
#  {'@ID': 'R01325',
#   'Name': 'Итальянская лира',
#   'EngName': 'Italian Lira',
#   'Nominal': '100000',
#   'ParentCode': 'R01325'},
#  {'@ID': 'R01335',
#   'Name': 'Казахстанский тенге',
#   'EngName': 'Kazakhstan Tenge',
#   'Nominal': '100',
#   'ParentCode': 'R01335'},
#  {'@ID': 'R01350',
#   'Name': 'Канадский доллар',
#   'EngName': 'Canadian Dollar',
#   'Nominal': '1',
#   'ParentCode': 'R01350'},
#  {'@ID': 'R01370',
#   'Name': 'Киргизский сом',
#   'EngName': 'Kyrgyzstan Som',
#   'Nominal': '100',
#   'ParentCode': 'R01370'},
#  {'@ID': 'R01375',
#   'Name': 'Китайский юань',
#   'EngName': 'China Yuan',
#   'Nominal': '10',
#   'ParentCode': 'R01375'},
#  {'@ID': 'R01390',
#   'Name': 'Кувейтский динар',
#   'EngName': 'Kuwaiti Dinar',
#   'Nominal': '10',
#   'ParentCode': 'R01390'},
#  {'@ID': 'R01405',
#   'Name': 'Латвийский лат',
#   'EngName': 'Latvian Lat',
#   'Nominal': '1',
#   'ParentCode': 'R01405'},
#  {'@ID': 'R01420',
#   'Name': 'Ливанский фунт',
#   'EngName': 'Lebanese Pound',
#   'Nominal': '100000',
#   'ParentCode': 'R01420'},
#  {'@ID': 'R01435',
#   'Name': 'Литовский лит',
#   'EngName': 'Lithuanian Lita',
#   'Nominal': '1',
#   'ParentCode': 'R01435'},
#  {'@ID': 'R01436',
#   'Name': 'Литовский талон',
#   'EngName': 'Lithuanian talon',
#   'Nominal': '1',
#   'ParentCode': 'R01435'},
#  {'@ID': 'R01500',
#   'Name': 'Молдавский лей',
#   'EngName': 'Moldova Lei',
#   'Nominal': '10',
#   'ParentCode': 'R01500'},
#  {'@ID': 'R01510',
#   'Name': 'Немецкая марка',
#   'EngName': 'Deutsche Mark',
#   'Nominal': '1',
#   'ParentCode': 'R01510'},
#  {'@ID': 'R01510A',
#   'Name': 'Немецкая марка',
#   'EngName': 'Deutsche Mark',
#   'Nominal': '100',
#   'ParentCode': 'R01510'},
#  {'@ID': 'R01523',
#   'Name': 'Нидерландский гульден',
#   'EngName': 'Netherlands Gulden',
#   'Nominal': '100',
#   'ParentCode': 'R01523'},
#  {'@ID': 'R01535',
#   'Name': 'Норвежская крона',
#   'EngName': 'Norwegian Krone',
#   'Nominal': '10',
#   'ParentCode': 'R01535'},
#  {'@ID': 'R01565',
#   'Name': 'Польский злотый',
#   'EngName': 'Polish Zloty',
#   'Nominal': '1',
#   'ParentCode': 'R01565'},
#  {'@ID': 'R01570',
#   'Name': 'Португальский эскудо',
#   'EngName': 'Portuguese Escudo',
#   'Nominal': '10000',
#   'ParentCode': 'R01570'},
#  {'@ID': 'R01585',
#   'Name': 'Румынский лей',
#   'EngName': 'Romanian Leu',
#   'Nominal': '10000',
#   'ParentCode': 'R01585'},
#  {'@ID': 'R01585F',
#   'Name': 'Румынский лей',
#   'EngName': 'Romanian Leu',
#   'Nominal': '10',
#   'ParentCode': 'R01585'},
#  {'@ID': 'R01589',
#   'Name': 'СДР (специальные права заимствования)',
#   'EngName': 'SDR',
#   'Nominal': '1',
#   'ParentCode': 'R01589'},
#  {'@ID': 'R01625',
#   'Name': 'Сингапурский доллар',
#   'EngName': 'Singapore Dollar',
#   'Nominal': '1',
#   'ParentCode': 'R01625'},
#  {'@ID': 'R01665A',
#   'Name': 'Суринамский доллар',
#   'EngName': 'Surinam Dollar',
#   'Nominal': '1',
#   'ParentCode': 'R01665'},
#  {'@ID': 'R01670',
#   'Name': 'Таджикский сомони',
#   'EngName': 'Tajikistan Ruble',
#   'Nominal': '10',
#   'ParentCode': 'R01670'},
#  {'@ID': 'R01670B',
#   'Name': 'Таджикский рубл',
#   'EngName': 'Tajikistan Ruble',
#   'Nominal': '10',
#   'ParentCode': 'R01670'},
#  {'@ID': 'R01700J',
#   'Name': 'Турецкая лира',
#   'EngName': 'Turkish Lira',
#   'Nominal': '1',
#   'ParentCode': 'R01700'},
#  {'@ID': 'R01710',
#   'Name': 'Туркменский манат',
#   'EngName': 'Turkmenistan Manat',
#   'Nominal': '10000',
#   'ParentCode': 'R01710'},
#  {'@ID': 'R01710A',
#   'Name': 'Новый туркменский манат',
#   'EngName': 'New Turkmenistan Manat',
#   'Nominal': '1',
#   'ParentCode': 'R01710'},
#  {'@ID': 'R01717',
#   'Name': 'Узбекский сум',
#   'EngName': 'Uzbekistan Sum',
#   'Nominal': '1000',
#   'ParentCode': 'R01717'},
#  {'@ID': 'R01720',
#   'Name': 'Украинская гривна',
#   'EngName': 'Ukrainian Hryvnia',
#   'Nominal': '10',
#   'ParentCode': 'R01720'},
#  {'@ID': 'R01720A',
#   'Name': 'Украинский карбованец',
#   'EngName': 'Ukrainian Hryvnia',
#   'Nominal': '1',
#   'ParentCode': 'R01720'},
#  {'@ID': 'R01740',
#   'Name': 'Финляндская марка',
#   'EngName': 'Finnish Marka',
#   'Nominal': '100',
#   'ParentCode': 'R01740'},
#  {'@ID': 'R01750',
#   'Name': 'Французский франк',
#   'EngName': 'French Franc',
#   'Nominal': '1000',
#   'ParentCode': 'R01750'},
#  {'@ID': 'R01760',
#   'Name': 'Чешская крона',
#   'EngName': 'Czech Koruna',
#   'Nominal': '10',
#   'ParentCode': 'R01760'},
#  {'@ID': 'R01770',
#   'Name': 'Шведская крона',
#   'EngName': 'Swedish Krona',
#   'Nominal': '10',
#   'ParentCode': 'R01770'},
#  {'@ID': 'R01775',
#   'Name': 'Швейцарский франк',
#   'EngName': 'Swiss Franc',
#   'Nominal': '1',
#   'ParentCode': 'R01775'},
#  {'@ID': 'R01790',
#   'Name': 'ЭКЮ',
#   'EngName': 'ECU',
#   'Nominal': '1',
#   'ParentCode': 'R01790'},
#  {'@ID': 'R01795',
#   'Name': 'Эстонская крона',
#   'EngName': 'Estonian Kroon',
#   'Nominal': '10',
#   'ParentCode': 'R01795'},
#  {'@ID': 'R01805',
#   'Name': 'Югославский новый динар',
#   'EngName': 'Yugoslavian Dinar',
#   'Nominal': '1',
#   'ParentCode': 'R01804'},
#  {'@ID': 'R01810',
#   'Name': 'Южноафриканский рэнд',
#   'EngName': 'S.African Rand',
#   'Nominal': '10',
#   'ParentCode': 'R01810'},
#  {'@ID': 'R01815',
#   'Name': 'Вон Республики Корея',
#   'EngName': 'South Korean Won',
#   'Nominal': '1000',
#   'ParentCode': 'R01815'},
#  {'@ID': 'R01820',
#   'Name': 'Японская иена',
#   'EngName': 'Japanese Yen',
#   'Nominal': '100',
#   'ParentCode': 'R01820'}]

# %%
curr_array = []
for item in data['Valuta']['Item']:
    curr_set = [item['Name'], item['EngName'], item['Nominal'], item['ParentCode']]
    curr_array.append(curr_set)
    print(curr_set)
# Out:
# ['Австралийский доллар', 'Australian Dollar', '1', 'R01010']
# ['Австрийский шиллинг', 'Austrian Shilling', '1000', 'R01015']
# ['Азербайджанский манат', 'Azerbaijan Manat', '1', 'R01020']
# ['Фунт стерлингов Соединенного королевства', 'British Pound Sterling', '1', 'R01035']
# ['Ангольская новая кванза', 'Angolan new Kwanza', '100000', 'R01040']
# ['Армянский драм', 'Armenia Dram', '1000', 'R01060']
# ['Белорусский рубль', 'Belarussian Ruble', '1', 'R01090']
# ['Бельгийский франк', 'Belgium Franc', '1000', 'R01095']
# ['Болгарский лев', 'Bulgarian lev', '1', 'R01100']
# ['Бразильский реал', 'Brazil Real', '1', 'R01115']
# ['Венгерский форинт', 'Hungarian Forint', '100', 'R01135']
# ['Гонконгский доллар', 'Hong Kong Dollar', '10', 'R01200']
# ['Греческая драхма', 'Greek Drachma', '10000', 'R01205']
# ['Датская крона', 'Danish Krone', '10', 'R01215']
# ['Доллар США', 'US Dollar', '1', 'R01235']
# ['Евро', 'Euro', '1', 'R01239']
# ['Индийская рупия', 'Indian Rupee', '100', 'R01270']
# ['Ирландский фунт', 'Irish Pound', '100', 'R01305']
# ['Исландская крона', 'Iceland Krona', '10000', 'R01310']
# ['Испанская песета', 'Spanish Peseta', '10000', 'R01315']
# ['Итальянская лира', 'Italian Lira', '100000', 'R01325']
# ['Казахстанский тенге', 'Kazakhstan Tenge', '100', 'R01335']
# ['Канадский доллар', 'Canadian Dollar', '1', 'R01350']
# ['Киргизский сом', 'Kyrgyzstan Som', '100', 'R01370']
# ['Китайский юань', 'China Yuan', '10', 'R01375']
# ['Кувейтский динар', 'Kuwaiti Dinar', '10', 'R01390']
# ['Латвийский лат', 'Latvian Lat', '1', 'R01405']
# ['Ливанский фунт', 'Lebanese Pound', '100000', 'R01420']
# ['Литовский лит', 'Lithuanian Lita', '1', 'R01435']
# ['Литовский талон', 'Lithuanian talon', '1', 'R01435']
# ['Молдавский лей', 'Moldova Lei', '10', 'R01500']
# ['Немецкая марка', 'Deutsche Mark', '1', 'R01510']
# ['Немецкая марка', 'Deutsche Mark', '100', 'R01510']
# ['Нидерландский гульден', 'Netherlands Gulden', '100', 'R01523']
# ['Норвежская крона', 'Norwegian Krone', '10', 'R01535']
# ['Польский злотый', 'Polish Zloty', '1', 'R01565']
# ['Португальский эскудо', 'Portuguese Escudo', '10000', 'R01570']
# ['Румынский лей', 'Romanian Leu', '10000', 'R01585']
# ['Румынский лей', 'Romanian Leu', '10', 'R01585']
# ['СДР (специальные права заимствования)', 'SDR', '1', 'R01589']
# ['Сингапурский доллар', 'Singapore Dollar', '1', 'R01625']
# ['Суринамский доллар', 'Surinam Dollar', '1', 'R01665']
# ['Таджикский сомони', 'Tajikistan Ruble', '10', 'R01670']
# ['Таджикский рубл', 'Tajikistan Ruble', '10', 'R01670']
# ['Турецкая лира', 'Turkish Lira', '1', 'R01700']
# ['Туркменский манат', 'Turkmenistan Manat', '10000', 'R01710']
# ['Новый туркменский манат', 'New Turkmenistan Manat', '1', 'R01710']
# ['Узбекский сум', 'Uzbekistan Sum', '1000', 'R01717']
# ['Украинская гривна', 'Ukrainian Hryvnia', '10', 'R01720']
# ['Украинский карбованец', 'Ukrainian Hryvnia', '1', 'R01720']
# ['Финляндская марка', 'Finnish Marka', '100', 'R01740']
# ['Французский франк', 'French Franc', '1000', 'R01750']
# ['Чешская крона', 'Czech Koruna', '10', 'R01760']
# ['Шведская крона', 'Swedish Krona', '10', 'R01770']
# ['Швейцарский франк', 'Swiss Franc', '1', 'R01775']
# ['ЭКЮ', 'ECU', '1', 'R01790']
# ['Эстонская крона', 'Estonian Kroon', '10', 'R01795']
# ['Югославский новый динар', 'Yugoslavian Dinar', '1', 'R01804']
# ['Южноафриканский рэнд', 'S.African Rand', '10', 'R01810']
# ['Вон Республики Корея', 'South Korean Won', '1000', 'R01815']
# ['Японская иена', 'Japanese Yen', '100', 'R01820']

# %%
curr_array
# Out:
# [['Австралийский доллар', 'Australian Dollar', '1', 'R01010'],
#  ['Австрийский шиллинг', 'Austrian Shilling', '1000', 'R01015'],
#  ['Азербайджанский манат', 'Azerbaijan Manat', '1', 'R01020'],
#  ['Фунт стерлингов Соединенного королевства',
#   'British Pound Sterling',
#   '1',
#   'R01035'],
#  ['Ангольская новая кванза', 'Angolan new Kwanza', '100000', 'R01040'],
#  ['Армянский драм', 'Armenia Dram', '1000', 'R01060'],
#  ['Белорусский рубль', 'Belarussian Ruble', '1', 'R01090'],
#  ['Бельгийский франк', 'Belgium Franc', '1000', 'R01095'],
#  ['Болгарский лев', 'Bulgarian lev', '1', 'R01100'],
#  ['Бразильский реал', 'Brazil Real', '1', 'R01115'],
#  ['Венгерский форинт', 'Hungarian Forint', '100', 'R01135'],
#  ['Гонконгский доллар', 'Hong Kong Dollar', '10', 'R01200'],
#  ['Греческая драхма', 'Greek Drachma', '10000', 'R01205'],
#  ['Датская крона', 'Danish Krone', '10', 'R01215'],
#  ['Доллар США', 'US Dollar', '1', 'R01235'],
#  ['Евро', 'Euro', '1', 'R01239'],
#  ['Индийская рупия', 'Indian Rupee', '100', 'R01270'],
#  ['Ирландский фунт', 'Irish Pound', '100', 'R01305'],
#  ['Исландская крона', 'Iceland Krona', '10000', 'R01310'],
#  ['Испанская песета', 'Spanish Peseta', '10000', 'R01315'],
#  ['Итальянская лира', 'Italian Lira', '100000', 'R01325'],
#  ['Казахстанский тенге', 'Kazakhstan Tenge', '100', 'R01335'],
#  ['Канадский доллар', 'Canadian Dollar', '1', 'R01350'],
#  ['Киргизский сом', 'Kyrgyzstan Som', '100', 'R01370'],
#  ['Китайский юань', 'China Yuan', '10', 'R01375'],
#  ['Кувейтский динар', 'Kuwaiti Dinar', '10', 'R01390'],
#  ['Латвийский лат', 'Latvian Lat', '1', 'R01405'],
#  ['Ливанский фунт', 'Lebanese Pound', '100000', 'R01420'],
#  ['Литовский лит', 'Lithuanian Lita', '1', 'R01435'],
#  ['Литовский талон', 'Lithuanian talon', '1', 'R01435'],
#  ['Молдавский лей', 'Moldova Lei', '10', 'R01500'],
#  ['Немецкая марка', 'Deutsche Mark', '1', 'R01510'],
#  ['Немецкая марка', 'Deutsche Mark', '100', 'R01510'],
#  ['Нидерландский гульден', 'Netherlands Gulden', '100', 'R01523'],
#  ['Норвежская крона', 'Norwegian Krone', '10', 'R01535'],
#  ['Польский злотый', 'Polish Zloty', '1', 'R01565'],
#  ['Португальский эскудо', 'Portuguese Escudo', '10000', 'R01570'],
#  ['Румынский лей', 'Romanian Leu', '10000', 'R01585'],
#  ['Румынский лей', 'Romanian Leu', '10', 'R01585'],
#  ['СДР (специальные права заимствования)', 'SDR', '1', 'R01589'],
#  ['Сингапурский доллар', 'Singapore Dollar', '1', 'R01625'],
#  ['Суринамский доллар', 'Surinam Dollar', '1', 'R01665'],
#  ['Таджикский сомони', 'Tajikistan Ruble', '10', 'R01670'],
#  ['Таджикский рубл', 'Tajikistan Ruble', '10', 'R01670'],
#  ['Турецкая лира', 'Turkish Lira', '1', 'R01700'],
#  ['Туркменский манат', 'Turkmenistan Manat', '10000', 'R01710'],
#  ['Новый туркменский манат', 'New Turkmenistan Manat', '1', 'R01710'],
#  ['Узбекский сум', 'Uzbekistan Sum', '1000', 'R01717'],
#  ['Украинская гривна', 'Ukrainian Hryvnia', '10', 'R01720'],
#  ['Украинский карбованец', 'Ukrainian Hryvnia', '1', 'R01720'],
#  ['Финляндская марка', 'Finnish Marka', '100', 'R01740'],
#  ['Французский франк', 'French Franc', '1000', 'R01750'],
#  ['Чешская крона', 'Czech Koruna', '10', 'R01760'],
#  ['Шведская крона', 'Swedish Krona', '10', 'R01770'],
#  ['Швейцарский франк', 'Swiss Franc', '1', 'R01775'],
#  ['ЭКЮ', 'ECU', '1', 'R01790'],
#  ['Эстонская крона', 'Estonian Kroon', '10', 'R01795'],
#  ['Югославский новый динар', 'Yugoslavian Dinar', '1', 'R01804'],
#  ['Южноафриканский рэнд', 'S.African Rand', '10', 'R01810'],
#  ['Вон Республики Корея', 'South Korean Won', '1000', 'R01815'],
#  ['Японская иена', 'Japanese Yen', '100', 'R01820']]
